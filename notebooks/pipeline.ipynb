# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    root_mean_squared_error,
    r2_score
)

from src.config import DADOS_TRATADOS
from src.auxiliares import dataframe_coeficientes
from src.graficos import plot_coeficientes, plot_residuos

sns.set_theme(palette='bright')

RANDOM_STATE = 42

# %%
df = pd.read_parquet(DADOS_TRATADOS)

df.head()
# Out:
#    idade  sexo        imc  pressao_media  colesterol_total         ldl   hdl  \
# 0     59     2  32.099998          101.0               157   93.199997  38.0
# 1     48     1  21.600000           87.0               183  103.199997  70.0
# 2     72     2  30.500000           93.0               156   93.599998  41.0
# 3     24     1  25.299999           84.0               198  131.399994  40.0
# 4     50     1  23.000000          101.0               192  125.400002  52.0
#
#    colesterol_hdl  triglicerides  glicose  target
# 0             4.0         4.8598       87     151
# 1             3.0         3.8918       69      75
# 2             4.0         4.6728       85     141
# 3             5.0         4.8903       89     206
# 4             4.0         4.2905       80     135

# %%
X = df.drop(columns='target')
y= df['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=RANDOM_STATE
)

pipeline = Pipeline(
    [
        ('scaler', StandardScaler()),
        ('reg', LinearRegression())
    ]
)

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('reg', LinearRegression())])

# %%
pipeline.score(X_test,y_test)
# Out:
# 0.45260268449783325

# %%
pipeline.named_steps
# Out:
# {'scaler': StandardScaler(), 'reg': LinearRegression()}

# %%
pipeline['reg'].coef_
# Out:
# array([  1.7537568, -11.511813 ,  25.60712  ,  16.828886 , -44.44888  ,
#         24.640959 ,   7.676985 ,  13.138786 ,  35.1612   ,   2.3513675],
#       dtype=float32)

# %%
coefs = dataframe_coeficientes(
    pipeline['reg'].coef_,
    X.columns
)

coefs
# Out:
#                   coeficiente
# colesterol_total   -44.448879
# sexo               -11.511813
# idade                1.753757
# glicose              2.351367
# hdl                  7.676985
# colesterol_hdl      13.138786
# pressao_media       16.828886
# ldl                 24.640959
# imc                 25.607121
# triglicerides       35.161201

# %%
plot_coeficientes(coefs, 'LinearRegression com StandarScaler')

# %%
pipeline['scaler']
# Out:
# StandardScaler()

# %%
pipeline['scaler'].transform(X)
# Out:
# array([[ 0.7917738 ,  1.0613699 ,  1.2701279 , ..., -0.06221033,
#          0.3913575 , -0.4043973 ],
#        [-0.0718379 , -0.9421786 , -1.127127  , ..., -0.8354584 ,
#         -1.4561754 , -1.9476647 ],
#        [ 1.8124058 ,  1.0613699 ,  0.9048321 , ..., -0.06221033,
#          0.03444809, -0.57587147],
#        ...,
#        [ 0.87028396,  1.0613699 , -0.37370417, ..., -0.24005738,
#         -1.0070797 ,  0.2814994 ],
#        [-1.0139598 , -0.9421786 ,  0.79067713, ...,  0.54865557,
#          0.9068729 , -0.57587147],
#        [-1.0139598 , -0.9421786 , -1.5837471 , ..., -0.8354584 ,
#         -0.11385107,  0.02428813]], shape=(442, 10), dtype=float32)

# %%
X_scaled = pipeline['scaler'].transform(X)

X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

sns.pairplot(X_scaled, diag_kind='kde')

# %%
X_scaled.mean()
# Out:
# idade              -0.031162
# sexo               -0.003865
# imc                -0.036766
# pressao_media      -0.024367
# colesterol_total    0.011641
# ldl                 0.016946
# hdl                 0.021053
# colesterol_hdl     -0.007891
# triglicerides      -0.025462
# glicose            -0.039142
# dtype: float32

# %%
X_scaled.std()
# Out:
# idade               1.029192
# sexo                1.000895
# imc                 1.008701
# pressao_media       0.983864
# colesterol_total    0.997925
# ldl                 1.001164
# hdl                 1.013668
# colesterol_hdl      0.997838
# triglicerides       0.997039
# glicose             0.985662
# dtype: float32

# %%
y_pred = pipeline.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 42.794097900390625

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 2900.194091796875

# %%
root_mean_squared_error(y_test, y_pred)
# Out:
# 53.853450775146484

# %%
r2_score(y_test, y_pred)
# Out:
# 0.45260268449783325

# %%
plot_residuos(y_test, y_pred)
